# %%
from IPython.display import display, Image

# %% [markdown]
# ### Question
# (https://leetcode.com/problems/insert-interval/)

# %%
display(Image('../images/057_Q.PNG'))

# %% [markdown]
# ### Solution 1

# %% [markdown]
# #### code

# %%
class Solution:
    def insert(self, intervals, newInterval):
        s, e = newInterval
        left = [elem for elem in intervals if elem[1] < s]
        right = [elem for elem in intervals if elem[0] > e]
        if left + right != intervals:
            s = min(s, intervals[len(left)][0])
            e = max(e, intervals[~len(right)][1])
        return left + [[s, e]] + right

# %% [markdown]
# #### test

# %%
intervals = [[1,3],[6,9]]
newInterval = [2,5]

# %%
s = Solution()

# %%
s.insert(intervals, newInterval)
# Out:
# [[1, 5], [6, 9]]

# %%
intervals = [[1,2],[3,5],[6,7],[8,10],[12,16]]
newInterval = [-2, -1]

# %%
s.insert(intervals, newInterval)
# Out:
# [[-2, -1], [1, 2], [3, 5], [6, 7], [8, 10], [12, 16]]

# %% [markdown]
# #### submit

# %%
display(Image('../images/057_S1.PNG'))
