# %%
from IPython.display import display, Image

# %% [markdown]
# ### Question
# (https://leetcode.com/problems/binary-tree-level-order-traversal/)

# %%
display(Image('../images/102_Q.PNG'))

# %% [markdown]
# ### Solution

# %% [markdown]
# #### code

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    def levelOrder(self, root):
        if not root:
            return []
        ans, level = [], [root]
        while level:
            ans.append([node.val for node in level])
            tmp = []
            for node in level:
                tmp.extend([node.left, node.right])
            level = [leaf for leaf in tmp if leaf]
        return ans

# %% [markdown]
# #### test

# %%
import math

# %%
def generate_tree(tree_vals):
    num_elem = len(tree_vals)
    num_level = math.log2(num_elem + 1)
    assert num_level % 1 == 0, 'wrong number in tree values...'
    # init all tree nodes
    ptree = []
    for i in range(num_elem):
        tmp_tree = TreeNode(tree_vals[i])
        ptree.append(tmp_tree)
    for i in range(int(num_elem / 2 - 1) + 1):
        ptree[i].left = ptree[2 * i + 1]
        ptree[i].right = ptree[2 * i + 2]
    return ptree[0]

# %%
tree_vals = [1,2,2,5,4,4,3]

# %%
root = generate_tree(tree_vals)

# %%
s = Solution()

# %%
s.levelOrder(root)
# Out:
# [[1], [2, 2], [5, 4, 4, 3]]

# %% [markdown]
# #### submit

# %%
display(Image('../images/102_S1.PNG'))
