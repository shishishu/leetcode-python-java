# %%
from IPython.display import display, Image

# %% [markdown]
# ### Question
# (https://leetcode.com/problems/middle-of-the-linked-list/)

# %%
display(Image('../images/876_Q.PNG'))

# %% [markdown]
# ### Solution 1: slow/fast

# %% [markdown]
# #### code

# %%
class Solution:
    def middleNode(self, head):
        slow, fast = head, head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        return slow

# %% [markdown]
# #### test

# %% [markdown]
# #### submit

# %%
display(Image('../images/876_S1.PNG'))
