# %%
from IPython.display import display, Image

# %% [markdown]
# ### Question
# (https://leetcode.com/problems/convert-sorted-array-to-binary-search-tree/)

# %%
display(Image('../images/108_Q.PNG'))

# %% [markdown]
# ### Solution 1: Recursive

# %% [markdown]
# #### code

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution:
    def sortedArrayToBST(self, nums):
        return self.convert(nums, 0, len(nums) - 1)
    def convert(self, nums, left, right):
        if left > right:
            return None
        mid = (left + right) // 2
        node = TreeNode(nums[mid])
        node.left = self.convert(nums, left, mid - 1)
        node.right = self.convert(nums, mid + 1, right)
        return node

# %% [markdown]
# #### test

# %%
nums = [-10,-3,0,5,9]

# %%
s = Solution()

# %%
s.sortedArrayToBST(nums)

# %% [markdown]
# #### submit

# %%
display(Image('../images/108_S1.PNG'))

# %% [markdown]
# ### Solution2

# %% [markdown]
# #### code

# %%
class Solution:
    def sortedArrayToBST(self, num):
        if not num:
            return None

        mid = len(num) // 2

        root = TreeNode(num[mid])
        root.left = self.sortedArrayToBST(num[:mid])
        root.right = self.sortedArrayToBST(num[mid+1:])

        return root

# %% [markdown]
# #### submit

# %%
display(Image('../images/108_S2.PNG'))
