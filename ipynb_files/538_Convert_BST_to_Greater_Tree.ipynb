# %%
from IPython.display import display, Image

# %% [markdown]
# ### Question
# (https://leetcode.com/problems/convert-bst-to-greater-tree/)

# %%
display(Image('../images/538_Q.PNG'))

# %% [markdown]
# ### Solution 1: Traverse

# %% [markdown]
# #### code

# %%
class Solution:
    def convertBST(self, root):
        def visit1(root):
            if root:
                visit1(root.left)
                vals.append(root.val)
                visit1(root.right)
        vals = []
        visit1(root)
        
        self.s = 0
        def visit2(root):
            if root:
                visit2(root.right)
                self.s += vals.pop()
                root.val = self.s
                visit2(root.left)
        visit2(root)
        
        return root

# %% [markdown]
# #### submit

# %%
display(Image('../images/538_S1.PNG'))

# %% [markdown]
# ### Solution 2: Traverse +

# %% [markdown]
# #### code

# %%
class Solution:
    def convertBST(self, root):
        self.val = 0
        def visit(root):
            if root:
                visit(root.right)
                root.val += self.val
                self.val = root.val
                visit(root.left)
        visit(root)
        return root

# %% [markdown]
# #### submit

# %%
display(Image('../images/538_S2.PNG'))

# %% [markdown]
# ### Solution 3: Iterative

# %% [markdown]
# #### code

# %%
class Solution:
    def convertBST(self, root):
        total = 0
        
        node = root
        stack = []
        while stack or node:
            while node:
                stack.append(node)
                node = node.right
            
            node = stack.pop()
            total += node.val
            node.val = total
            
            node = node.left
        return root

# %% [markdown]
# #### submit

# %%
display(Image('../images/538_S3.PNG'))
